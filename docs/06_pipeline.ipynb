# %% [markdown]
# # 🔄 06 — Final Pipeline
#
# Runs the complete end-to-end training pipeline defined in `src/pipeline.py`

# %%
from src.pipeline import run_training_pipeline

run_training_pipeline()

# %% [markdown]
# Pipeline complete!
# Model + preprocessor + threshold saved in `/models`.
